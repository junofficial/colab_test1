# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PROJ_path = "/content/drive/MyDrive/Colab Notebooks/colab_test1/"
# %cd "{PROJ_path}"
# %pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/colab_test1
# '/content/drive/MyDrive/Colab Notebooks/colab_test1'

# %%
with open(PROJ_path + "test.txt","r") as f:
  c = f.read()
print(c)
# Out:
# test

# %%
# !git config user.email "junho1458@gmail.com"
# !git config user.name "junofficial"

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Untitled0.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add prac1.ipynb
# !git commit -m "prac1 initial commit"
# !git push origin main
# Out:
# fatal: pathspec 'prac1.ipynb' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Untitled0.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)
# Everything up-to-date
